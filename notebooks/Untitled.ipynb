# %%
import wfdb
import numpy as np
signal, fields = wfdb.rdsamp("../data/CODE-15/micro/1000271")
signal = np.transpose(signal)

# %%
signal
# Out:
# array([[ 1.000e-03,  0.000e+00, -3.000e-03, ..., -8.570e-01, -8.690e-01,
#         -8.770e-01],
#        [ 1.000e-03,  0.000e+00, -2.000e-03, ..., -7.770e-01, -7.800e-01,
#         -7.860e-01],
#        [ 0.000e+00,  0.000e+00,  1.000e-03, ...,  8.100e-02,  8.900e-02,
#          9.100e-02],
#        ...,
#        [ 1.000e-03,  0.000e+00, -1.000e-03, ..., -6.630e-01, -6.610e-01,
#         -6.650e-01],
#        [ 0.000e+00,  0.000e+00,  1.000e-03, ...,  3.440e-01,  3.390e-01,
#          3.340e-01],
#        [ 2.000e-03,  0.000e+00, -5.000e-03, ..., -1.796e+00, -1.797e+00,
#         -1.798e+00]])

# %%
from matplotlib import pyplot as plt
plt.plot(signal)
# Out:
# ...
#  ...]

# %%
signal.shape
# Out:
# (12, 3637)

# %%
fig, axis = plt.subplots(12, 1)
x = list(range(len(signal[0])))
for i in range(12):
    axis[i].plot(x, signal[i])
plt.show()
